# %% [markdown]
# <a href="https://colab.research.google.com/github/jlonotbot/ML_23F_unav/blob/main/notbots_ML_23F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Prueba de GITHUB

# %%
print("hola mundo")

# %%
prueba2
